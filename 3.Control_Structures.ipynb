# %%
#if
if():
    print()

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 20

# %%
if(age==20):
    print("Adult")
# Out:
# Adult

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 18

# %%
if(age<20):
    print("Children")
else:
    print("Adult")
# Out:
# Children

# %%
age=int(input("Enter the age:"))
# Out:
# Enter the age: 25

# %%
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
#for loop

# %%
lists=[22,46,65,32,85]

# %%
for temp in lists:
    print(temp)
# Out:
# 22
# 46
# 65
# 32
# 85

# %%
for age in lists:
    if(age<18):
        print("Children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Citizen
# Senior Citizen
# Adult
# Senior Citizen

# %%
num=int(input("Enter the number"))
# Out:
# Enter the number 4

# %%
if((num%2)==0):
    print("Even number")
else:
    print("Odd number")
# Out:
# Even number

# %%
range(0,10)
# Out:
# range(0, 10)

# %%
print(range(0,10))
# Out:
# range(0, 10)

# %%
for num in range(11,20):
    print(num)
# Out:
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
